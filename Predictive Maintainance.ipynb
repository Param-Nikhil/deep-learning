# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # the given columns
# columns =
# 0:'engineNumber'
# 1:'cycleNumber'
# 2:'opSetting1'
# 3:'opSetting2'
# 4:'opSetting3'
# 5:'sensor1'
# 6:'sensor2'
# 7:'sensor3'
# 8:'sensor4'
# 9:'sensor5'
# 10:'sensor6'
# 11:'sensor7'
# 12:'sensor8'
# 13:'sensor9'
# 14:'sensor10'
# 15:'sensor11'
# 16:'sensor12'
# 17:'sensor13'
# 18:'sensor14'
# 19:'sensor15'
# 20:'sensor16'
# 21:'sensor17'
# 22:'sensor18'
# 23:'sensor19'
# 24:'sensor20'
# 25:'sensor21'

# %%
import os
for dirname, _, filenames in os.walk('/content/drive/MyDrive/Prof Tarachand/CMaps'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /content/drive/MyDrive/Prof Tarachand/CMaps/test_FD003.txt
# /content/drive/MyDrive/Prof Tarachand/CMaps/test_FD004.txt
# /content/drive/MyDrive/Prof Tarachand/CMaps/RUL_FD002.txt
# /content/drive/MyDrive/Prof Tarachand/CMaps/RUL_FD004.txt
# /content/drive/MyDrive/Prof Tarachand/CMaps/test_FD001.txt
# /content/drive/MyDrive/Prof Tarachand/CMaps/test_FD002.txt
# /content/drive/MyDrive/Prof Tarachand/CMaps/readme.txt
# /content/drive/MyDrive/Prof Tarachand/CMaps/RUL_FD003.txt
# /content/drive/MyDrive/Prof Tarachand/CMaps/Damage Propagation Modeling.pdf
# /content/drive/MyDrive/Prof Tarachand/CMaps/RUL_FD001.txt
# /content/drive/MyDrive/Prof Tarachand/CMaps/train_FD002.txt
# /content/drive/MyDrive/Prof Tarachand/CMaps/train_FD001.txt
# /content/drive/MyDrive/Prof Tarachand/CMaps/train_FD004.txt
# /content/drive/MyDrive/Prof Tarachand/CMaps/train_FD003.txt
# /content/drive/MyDrive/Prof Tarachand/CMaps/x.txt

# %%
tx=pd.read_csv('/content/drive/MyDrive/Prof Tarachand/CMaps/train_FD001.txt',sep=' ',header=None);
tx
# Out:
#         0    1       2       3      4   ...     23     24       25  26  27
# 0        1    1 -0.0007 -0.0004  100.0  ...  100.0  39.06  23.4190 NaN NaN
# 1        1    2  0.0019 -0.0003  100.0  ...  100.0  39.00  23.4236 NaN NaN
# 2        1    3 -0.0043  0.0003  100.0  ...  100.0  38.95  23.3442 NaN NaN
# 3        1    4  0.0007  0.0000  100.0  ...  100.0  38.88  23.3739 NaN NaN
# 4        1    5 -0.0019 -0.0002  100.0  ...  100.0  38.90  23.4044 NaN NaN
# ...    ...  ...     ...     ...    ...  ...    ...    ...      ...  ..  ..
# 20626  100  196 -0.0004 -0.0003  100.0  ...  100.0  38.49  22.9735 NaN NaN
# 20627  100  197 -0.0016 -0.0005  100.0  ...  100.0  38.30  23.1594 NaN NaN
# 20628  100  198  0.0004  0.0000  100.0  ...  100.0  38.44  22.9333 NaN NaN
# 20629  100  199 -0.0011  0.0003  100.0  ...  100.0  38.29  23.0640 NaN NaN
# 20630  100  200 -0.0032 -0.0005  100.0  ...  100.0  38.37  23.0522 NaN NaN
#
# [20631 rows x 28 columns]

# %%
tx.tail(10)
# Out:
#         0    1       2       3      4   ...     23     24       25  26  27
# 20621  100  191 -0.0005 -0.0000  100.0  ...  100.0  38.39  23.1218 NaN NaN
# 20622  100  192 -0.0009  0.0001  100.0  ...  100.0  38.56  23.0770 NaN NaN
# 20623  100  193 -0.0001  0.0002  100.0  ...  100.0  38.47  23.0230 NaN NaN
# 20624  100  194 -0.0011  0.0003  100.0  ...  100.0  38.38  23.1324 NaN NaN
# 20625  100  195 -0.0002 -0.0001  100.0  ...  100.0  38.14  23.1923 NaN NaN
# 20626  100  196 -0.0004 -0.0003  100.0  ...  100.0  38.49  22.9735 NaN NaN
# 20627  100  197 -0.0016 -0.0005  100.0  ...  100.0  38.30  23.1594 NaN NaN
# 20628  100  198  0.0004  0.0000  100.0  ...  100.0  38.44  22.9333 NaN NaN
# 20629  100  199 -0.0011  0.0003  100.0  ...  100.0  38.29  23.0640 NaN NaN
# 20630  100  200 -0.0032 -0.0005  100.0  ...  100.0  38.37  23.0522 NaN NaN
#
# [10 rows x 28 columns]

# %%
trainx_fd1=pd.read_csv('/content/drive/MyDrive/Prof Tarachand/CMaps/train_FD001.txt',sep = " ", header = None);
testx_fd1=pd.read_csv('/content/drive/MyDrive/Prof Tarachand/CMaps/test_FD001.txt',sep = " ", header = None);

# %%
col = {0:'engineNumber',1:'cycleNumber',2:'opSetting1',3:'opSetting2',4:'opSetting3',5:'sensor1',6:'sensor2',
           7:'sensor3',8:'sensor4',9:'sensor5',10:'sensor6',11:'sensor7',12:'sensor8',13:'sensor9',14:'sensor10',
           15:'sensor11',16:'sensor12',17:'sensor13',18:'sensor14',19:'sensor15',20:'sensor16',
           21:'sensor17',22:'sensor18',23:'sensor19',24:'sensor20',25:'sensor21'}

# %%
train_fd1
# Out:
#        engineNumber  cycleNumber  opSetting1  ...  sensor19  sensor20  sensor21
# 0                 1            1     -0.0007  ...     100.0     39.06   23.4190
# 1                 1            2      0.0019  ...     100.0     39.00   23.4236
# 2                 1            3     -0.0043  ...     100.0     38.95   23.3442
# 3                 1            4      0.0007  ...     100.0     38.88   23.3739
# 4                 1            5     -0.0019  ...     100.0     38.90   23.4044
# ...             ...          ...         ...  ...       ...       ...       ...
# 20626           100          196     -0.0004  ...     100.0     38.49   22.9735
# 20627           100          197     -0.0016  ...     100.0     38.30   23.1594
# 20628           100          198      0.0004  ...     100.0     38.44   22.9333
# 20629           100          199     -0.0011  ...     100.0     38.29   23.0640
# 20630           100          200     -0.0032  ...     100.0     38.37   23.0522
#
# ...

# %%
test_fd1
# Out:
#        engineNumber  cycleNumber  opSetting1  ...  sensor19  sensor20  sensor21
# 0                 1            1      0.0023  ...     100.0     38.86   23.3735
# 1                 1            2     -0.0027  ...     100.0     39.02   23.3916
# 2                 1            3      0.0003  ...     100.0     39.08   23.4166
# 3                 1            4      0.0042  ...     100.0     39.00   23.3737
# 4                 1            5      0.0014  ...     100.0     38.99   23.4130
# ...             ...          ...         ...  ...       ...       ...       ...
# 13091           100          194      0.0049  ...     100.0     38.65   23.1974
# 13092           100          195     -0.0011  ...     100.0     38.57   23.2771
# 13093           100          196     -0.0006  ...     100.0     38.62   23.2051
# 13094           100          197     -0.0038  ...     100.0     38.66   23.2699
# 13095           100          198      0.0013  ...     100.0     38.70   23.1855
#
# ...

# %%
train_fd1=trainx_fd1.rename(mapper=col,axis=1);
test_fd1=testx_fd1.rename(mapper=col,axis=1);

# %%
train_fd1=train_fd1.dropna(axis=1,inplace=False)
test_fd1.dropna(axis=1,inplace=True)

# %%
test_fd1.drop(columns=['engineNumber','cycleNumber'])
train_fd1.drop(columns=['engineNumber','cycleNumber'])
# Out:
#        opSetting1  opSetting2  opSetting3  ...  sensor19  sensor20  sensor21
# 0         -0.0007     -0.0004       100.0  ...     100.0     39.06   23.4190
# 1          0.0019     -0.0003       100.0  ...     100.0     39.00   23.4236
# 2         -0.0043      0.0003       100.0  ...     100.0     38.95   23.3442
# 3          0.0007      0.0000       100.0  ...     100.0     38.88   23.3739
# 4         -0.0019     -0.0002       100.0  ...     100.0     38.90   23.4044
# ...           ...         ...         ...  ...       ...       ...       ...
# 20626     -0.0004     -0.0003       100.0  ...     100.0     38.49   22.9735
# 20627     -0.0016     -0.0005       100.0  ...     100.0     38.30   23.1594
# 20628      0.0004      0.0000       100.0  ...     100.0     38.44   22.9333
# 20629     -0.0011      0.0003       100.0  ...     100.0     38.29   23.0640
# 20630     -0.0032     -0.0005       100.0  ...     100.0     38.37   23.0522
#
# [20631 rows x 24 columns]

# %%
from sklearn.preprocessing import MinMaxScaler 
SCL=MinMaxScaler();
train_fd1_SCL = pd.DataFrame(SCL.fit_transform(train_fd1), 
                              columns=train_fd1.columns, 
                              index=train_fd1.index)
train_fd1_SCL.describe()
# Out:
#        engineNumber   cycleNumber  ...      sensor20      sensor21
# count  20631.000000  20631.000000  ...  20631.000000  20631.000000
# mean       0.510167      0.298637  ...      0.524241      0.546127
# std        0.295229      0.190806  ...      0.140114      0.149476
# min        0.000000      0.000000  ...      0.000000      0.000000
# 25%        0.252525      0.141274  ...      0.434109      0.452361
# 50%        0.515152      0.285319  ...      0.534884      0.557443
# 75%        0.767677      0.429363  ...      0.627907      0.652582
# max        1.000000      1.000000  ...      1.000000      1.000000
#
# [8 rows x 26 columns]
